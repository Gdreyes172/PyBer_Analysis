# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statistics

# %%
pH_lvl = [1.2,1.55,7,12.4,2.3,5.4,6.7]
Substance = ["HCl", "Orange Jc","H2O","Bleach","Milk","Blood","Semen"]

# %%
# Rename x_axis and y_axis to something easier to type
Sub = Substance
pH = pH_lvl
plt.title("pH of Common Items")
plt.xlabel("Substances")
plt.ylabel("pH Level")
plt.plot(Sub, pH)
plt.show()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]
Month = x_axis
Dollas = y_axis

# %%
# Create the plot
plt.plot(Month, Dollas)

# %%
#Create a the plot with ax.plt() a
fig, ax = plt.subplots()
ax.plot(Month, Dollas)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(Month, Dollas)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(Month, Dollas)

# %%
# Create the plot.
plt.plot(Month, Dollas)
plt.show()

# %%
class Robot:
    def __init__(self, Model, Modelnum):
        self.M = Model
        self.Mn = Modelnum

class Robot_t(Robot): 
    def __init__(self, Model, Modelnum):
        super().__init__(Model, Modelnum)
        self.t = Modelnum
        Type = self.t
        if Type > 10:
            return self.combat()
        else:
            return self.support()
    def support(self):    
        print(f"I am {self.M} {self.Mn}. Awaiting support role.")
    def combat(self):
        print(f"I am {self.M} {self.Mn}. Ready for combat!")

# %%
r1 = Robot_t("MK", 11)
r2 = Robot_t("RS", 4)
# Out:
# I am MK 11. Ready for combat!
# I am RS 4. Awaiting support role.

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 50.
plt.ylim(5, 50)
# Testing the xlim function
plt.xlim()
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.title("PyBer Fare by Month", fontweight='bold')
plt.xlabel("Fare ($)", fontweight='bold')
plt.ylabel("Date", fontweight='bold')
plt.xlim(0, 50)
plt.gca().invert_yaxis()
plt.barh(x_axis, y_axis, color= 'magenta', label = 'Boston')
plt.legend()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color= 'cyan', label= 'Chicago')
ax.legend()
ax.invert_yaxis()
ax.set_xlabel("Fare ($)", fontweight = 'bold')
ax.set_ylabel("Date", fontweight = 'bold')
ax.set_title("PyBer Fare by Month", fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]


plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)
plt.scatter(x_axis, y_axis, s=y_axis_larger, label= 'Chicago')
plt.xlabel("Dates")
plt.ylabel("Fares ($)")
plt.title("PyBer Fare per Month")
plt.legend()

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*5)
plt.scatter(y_axis, x_axis, s=y_axis_larger, color= 'skyblue', label= 'Chicago', alpha=.80, edgecolors ='black', linewidth=2)
plt.xlabel("Dates")
plt.ylabel("Fares ($)")
plt.title("PyBer Fare per Month")
plt.legend()
plt.gca().invert_yaxis()

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Get the standard deviation of the values in the y-axis.
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0, 51, step=5.0))
plt.gca().invert_yaxis()

# %%
from matplotlib.ticker import MultipleLocator
# Increase the size of the plot figure.
fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))

# Create minor ticks at an increment of 1.
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()

# %%
np.arange(0, 51, step =5.0)
# Out:
# array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45., 50.])
